# %%
cd E:\Depaulll\7.Fall\Image Processing\Final\data\cohn-kanade\cohn-kanade
# Out:
# E:\Depaulll\7.Fall\Image Processing\Final\data\cohn-kanade\cohn-kanade

# %%
import sys
import os
sys.path.append('e:\\anacode\\lib\\site-packages')

# %%
import pandas as pd
import numpy as np
import sklearn
from numpy import *
import time
import graphviz
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob
# %matplotlib inline

# %%
#import keras
#import cv2
#import mlxtend
#import tensorflow
#import theano
#import xgboost

# %%
all_im = []
norm = []
a = []
b = []
c = []
d = []
e = []
f = []
count = 0
for root, dirs, files in os.walk(".", topdown=False):
    #for name in files:
    #    print(os.path.join(root, name))
    #for name in dirs:
    #   print(os.path.join(root, name))
    #for root in root:
    #    print(root)
    
    if len(dirs) == 6:
        count += 1
        for file in files: 
            if '001' in file:
                print(file)
            if '002' in file:
                print(file)
            if '003' in file:
                print(file)
            if '004' in file:
                print(file)
            if '005' in file:
                print(file)
            if '006' in file:
                print(file)
        
        
        
        #print(dirs)
        #print(root)
        #print(files)
        #print(dirs)
        #print(os.path.join(root, dirs))
        #for name in dirs:
            #print(dirs)
            #if name.endswith('png')

# %%
count
# Out:
# 24

# %%
for root, dirs, files in os.walk(".", topdown=False):
    print(files)
    #for file in files:
        #print(os.path.join(root, file))
        #print(file)
        #print(type(files))
    #for dirc in dirs:
        #print(os.path.join(root, dirc))
# Out:
# ['S010_001_01594215.png', 'S010_001_01594216.png', 'S010_001_01594217.png', 'S010_001_01594218.png', 'S010_001_01594219.png', 'S010_001_01594220.png', 'S010_001_01594221.png', 'S010_001_01594222.png', 'S010_001_01594223.png', 'S010_001_01594224.png', 'S010_001_01594225.png', 'S010_001_01594226.png']
# ['S010_002_01593819.png', 'S010_002_01593820.png', 'S010_002_01593821.png', 'S010_002_01593822.png', 'S010_002_01593823.png', 'S010_002_01593824.png', 'S010_002_01593825.png', 'S010_002_01593826.png', 'S010_002_01593827.png', 'S010_002_01593828.png', 'S010_002_01593829.png', 'S010_002_01593900.png', 'S010_002_01593901.png', 'S010_002_01593902.png']
# ...

# %%
type(root)
# Out:
# str

# %%
type(dirs)
# Out:
# list

# %%
type(files)
# Out:
# list

# %%
len(dirs)
# Out:
# 97

# %%
len(files)
# Out:
# 0

# %%
cd E:\Depaulll\7.Fall\Image Processing\Final\data\cohn-kanade\cohn-kanade
# Out:
# E:\Depaulll\7.Fall\Image Processing\Final\data\cohn-kanade\cohn-kanade

# %%
pwd
# Out:
# 'E:\\Depaulll\\7.Fall\\Image Processing\\Final\\data\\cohn-kanade\\cohn-kanade'

# %%
#path = 'E:\Depaulll\7.Fall\Image Processing\Final\data\cohn-kanade\cohn-kanade\S010\001\*'
path = 'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/*'

# %%
img_list = glob.glob(path)

# %%
#img_list

# %%
glob.glob(path);

# %%
all_im = []
norm = []
a = []
b = []
c = []
d = []
e = []
f = []
count = 0

# %%
img_list[1].replace('\\','/')
# Out:
# 'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S011'

# %%
for folder in img_list:
    folder = folder.replace('\\','/')
    path = folder + '/*'
    #list of expressions folder for each instance
    expr = glob.glob(path)
    #print(expr)
    #print(len(expr))
    if len(expr) == 6:
        for expression in expr:
            expression = expression.replace('\\','/')
            expression = expression + '/*'
            #print(expression)
            image_list = glob.glob(expression)
            #print(image_list)
            #each image_list is a expression of an instance
            if expression.endswith('001/*'):
                a.append(image_list[len(image_list)-1])
                #for image in image_list:
                    #image = image.replace('\\','/')
                    #print(image)
                    #print(len(image_list))
                    #picture = mpimg.imread(image)
                    #plt.imshow(picture)
            elif expression.endswith('002/*'):
                b.append(image_list[len(image_list)-1])
            elif expression.endswith('003/*'):
                c.append(image_list[len(image_list)-1])
            elif expression.endswith('004/*'):
                d.append(image_list[len(image_list)-1])
            elif expression.endswith('005/*'):
                e.append(image_list[len(image_list)-1])
            elif expression.endswith('001/*'):
                f.append(image_list[len(image_list)-1])

# %%
expr
# Out:
# ['E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S138\\001',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S138\\002',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S138\\003',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S138\\004',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S138\\005',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S138\\006']

# %%
a
# Out:
# ['E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S010/001\\S010_001_01594226.png',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S011/001\\S011_001_03141509.png',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S022/001\\S022_001_00021417.png',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S026/001\\S026_001_01383511.png',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S032/001\\S032_001_01345811.png',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S035/001\\S035_001_02500816.png',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S037/001\\S037_001_00233525.png',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S042/001\\S042_001_01435126.png',
#  'E:/Depaulll/7.Fall/Image Processing/Final/data/cohn-kanade/cohn-kanade/S044/001\\S044_001_00044207.png',
# ...

# %%
len(b)
# Out:
# 24

# %%
img = a[9]

# %%
picture = mpimg.imread(img)
plt.imshow(picture)

# %%
img = b[2]
picture = mpimg.imread(img)
plt.imshow(picture)

# %%
#Face detection
import cv2

# %%
#C:/Users/Minh/Downloads/opencv/opencv/sources/data/haarcascades_cuda/haarcascade_frontalface_default.xml
#C:/Users/Minh/Downloads/opencv/opencv/sources/data/haarcascades_cuda/haarcascade_eye.xml

# %%
#face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
#img = cv2.imread(img)
#gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faceCascade = cv2.CascadeClassifier('C:/Users/Minh/Downloads/opencv/opencv/sources/data/haarcascades_cuda/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('C:/Users/Minh/Downloads/opencv/opencv/sources/data/haarcascades_cuda/haarcascade_eye.xml')
img = cv2.imread(img)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
#faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#for (x,y,w,h) in faces:
#    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#    roi_gray = gray[y:y+h, x:x+w]
#    roi_color = img[y:y+h, x:x+w]
#    eyes = eye_cascade.detectMultiScale(roi_gray)
#    for (ex,ey,ew,eh) in eyes:
#        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
#cv2.imshow('img',img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30),
    flags = cv2.CASCADE_SCALE_IMAGE
)

# %%
print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    #cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
    print(x,y,w,h)
# Out:
# Found 1 faces!
# 220 89 256 256

# %%
#face detection
cv2.imshow("Faces found" ,img)
cv2.waitKey(0)
# Out:
# -1

# %%
#face landmark
#import dlib

# %%
faces
# Out:
# array([[220,  89, 256, 256]], dtype=int32)

# %%
crop = img[x-np.int32(w/2):x+np.int32(w/2),y+np.int32(h/2):y+np.int32(3*h/2)]
cv2.imshow('cropped',crop)
cv2.waitKey(0)
# Out:
# -1

# %%
img.shape
# Out:
# (490, 640, 3)

# %%
crop.shape
# Out:
# (256, 256, 3)

# %%
import numpy
